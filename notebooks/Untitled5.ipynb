# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
times = [50, 100, 200, 400, 600, 800, 1000]
colors = plt.cm.cool(np.linspace(0, 1, len(times)))

for n, i in enumerate(times):
    if i == 1000:
        eigvals = np.loadtxt('../com_covar_eig')
    else:
        eigvals = np.loadtxt('../' + str(i) + 'ns/com_covar_eig')
                     
    plt.plot(np.arange(1, 223), eigvals[:-6], lw = 2, c = colors[n], label = str(i) + 'ns')
plt.xscale('log')
plt.yscale('log')
plt.legend()
plt.show()
plt.close()

# %%
times = [50, 100, 200, 400, 600, 800, 1000]
colors = plt.cm.cool(np.linspace(0, 1, len(times)))

QT = np.loadtxt(np.reshape('../com_Rmatrix'), (228, 228)).T
for n, i in enumerate(times):
    if i == 1000:
        Q = np.loadtxt(np.reshape('../com_Rmatrix'), (228, 228))
    else:
        Q = np.loadtxt(np.reshape('../' + str(i) + 'ns/com_Rmatrix'), (228, 228))
                     
    plt.plot(np.arange(1, 223), eigvals[:-6], lw = 2, c = colors[n], label = str(i) + 'ns')
plt.xscale('log')
plt.yscale('log')
plt.legend()
plt.show()
plt.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-1150c6359052> in <module>
# ----> 1 times
#
# NameError: name 'times' is not defined
